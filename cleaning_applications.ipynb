# %% [markdown]
# ## Cleaning Enrollments/Pathways
#
# #### Notes
# This will be useful for further insights about applicant demographics

# %%
# importing the necessary modules
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('data/ARC Application.xlsx')

df.head()
# Out:
#   KY Region Contact: Auto Id  Contact: Unique ID SSN  Contact: SSN Opt Out  \
# 0      SOAR      202109-5224                     NaN                     0
# 1      SOAR      202109-5230                     NaN                     0
# 2      SOAR      202109-5233                     NaN                     0
# 3      SOAR      202109-5236                     NaN                     0
# 4      SOAR      202109-5237                     NaN                     0
#
#   Contact: Mailing State/Province Contact: County  \
# 0                              KY            Knox
# 1                              KY           Perry
# 2                              KY          Morgan
# 3                              KY           Floyd
# 4                              KY            Knox
#
#    Contact: Mailing Zip/Postal Code Contact: Birthdate    Contact: Gender  \
# 0                             40906         1981-10-25             Female
# 1                             41773         2000-10-28  Prefer not to say
# 2                             41472         1986-11-05               Male
# 3                             41669         1978-01-22             Female
# 4                             40906         1992-04-16               Male
#
#   Disability  ... Displaced Homemaker Spouse of Armed Forces Reduced Income  \
# 0         No  ...                 NaN                                   NaN
# 1         No  ...                 NaN                                   NaN
# 2        Yes  ...                 NaN                                   NaN
# 3         No  ...                 Yes                                    No
# 4         No  ...                 NaN                                   NaN
#
#   Loss of Family Support Seasonal farm worker?  Contact: First Name  \
# 0                    NaN                   NaN                 name
# 1                    NaN                   NaN                 name
# 2                    NaN                   NaN                 name
# 3                     No                    No                 name
# 4                    NaN                   NaN                 name
#
#   Contact: Last Name                       Status Date Completed  \
# 0               name  Accepted - Prework Complete     2021-08-24
# 1               name  Accepted - Prework Complete     2021-08-25
# 2               name  Accepted - Prework Complete     2021-08-24
# 3               name  Accepted - Prework Complete     2021-08-24
# 4               name  Accepted - Prework Complete     2021-08-24
#
#    Assessment: Created Date Contact: Approval Status
# 0                2021-09-10                      NaN
# 1                2021-09-10                      NaN
# 2                2021-09-10                      NaN
# 3                2021-09-10                      NaN
# 4                2021-09-10                      NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# #### Preliminary Thoughts
# There are a lot of columns and empty values in this at first glance.  This will be useful for a demographical view of who's exactly applying to be a part of the CODE:You program.  Consider merging this with the 'all demographics and programs' dataFrame for further insights on specific demographics that aren't necessarily recorded there.

# %%
check_cols = df.columns

print(check_cols)
# Out:
# Index(['KY Region', 'Contact: Auto Id', 'Contact: Unique ID SSN',
#        'Contact: SSN Opt Out', 'Contact: Mailing State/Province',
#        'Contact: County', 'Contact: Mailing Zip/Postal Code',
#        'Contact: Birthdate', 'Contact: Gender', 'Disability',
#        'Primary Disability', 'Contact: Race', 'Contact: Veteran',
#        'Employment Status', 'Unemployment Insurance', 'Long-term unemployment',
#        'Highest level of education completed', 'Enrolled in school?', 'TANF',
#        'Within Two Years of Exhausting TANF?', 'SSI', 'SNAP', 'Homeless',
#        'What is your housing situation?', 'Justice Involvement', 'Low Income',
#        'English Language Learner', 'Comfortably Read and Write in English?',
#        'Cultural barriers?', 'Single Parent', 'Displaced Homemaker',
#        'Spouse of Armed Forces Reduced Income', 'Loss of Family Support',
#        'Seasonal farm worker?', 'Contact: First Name', 'Contact: Last Name',
#        'Status', 'Date Completed', 'Assessment: Created Date',
#        'Contact: Approval Status'],
#       dtype='object')

# %%
df.count() # seeing how full each column is
# Out:
# KY Region                                 2476
# Contact: Auto Id                          2476
# Contact: Unique ID SSN                       0
# Contact: SSN Opt Out                      2476
# Contact: Mailing State/Province           2476
# Contact: County                           2475
# Contact: Mailing Zip/Postal Code          2476
# Contact: Birthdate                        2476
# Contact: Gender                           2476
# Disability                                2475
# Primary Disability                         214
# Contact: Race                             2476
# Contact: Veteran                          2475
# Employment Status                         2475
# Unemployment Insurance                    2476
# Long-term unemployment                     283
# Highest level of education completed      2475
# Enrolled in school?                       2475
# TANF                                      2476
# Within Two Years of Exhausting TANF?       281
# SSI                                       2476
# SNAP                                      2476
# Homeless                                  1314
# What is your housing situation?           2451
# Justice Involvement                       2453
# Low Income                                2475
# English Language Learner                  2431
# Comfortably Read and Write in English?     283
# Cultural barriers?                         283
# Single Parent                              282
# Displaced Homemaker                        283
# Spouse of Armed Forces Reduced Income       82
# Loss of Family Support                      81
# Seasonal farm worker?                      282
# Contact: First Name                       2476
# Contact: Last Name                        2476
# Status                                    1706
# Date Completed                             788
# Assessment: Created Date                  2476
# Contact: Approval Status                     0
# dtype: int64

# %% [markdown]
# #### Unique elements
#
# Next, we'll go about finding unique elements to further weed through the data.  If there's 1 or less, then the data can be dropped and mentioned in notes.

# %%
unique_elements = df.nunique() # finding the unique elements per column

print(unique_elements)
# Out:
# KY Region                                    1
# Contact: Auto Id                          2013
# Contact: Unique ID SSN                       0
# Contact: SSN Opt Out                         2
# Contact: Mailing State/Province              3
# Contact: County                             59
# Contact: Mailing Zip/Postal Code           329
# Contact: Birthdate                        1819
# Contact: Gender                              6
# Disability                                   3
# Primary Disability                           8
# Contact: Race                               24
# Contact: Veteran                             2
# Employment Status                            6
# Unemployment Insurance                       2
# Long-term unemployment                       2
# Highest level of education completed        13
# Enrolled in school?                          2
# TANF                                         2
# Within Two Years of Exhausting TANF?         3
# SSI                                          2
# SNAP                                         2
# Homeless                                     2
# What is your housing situation?              8
# Justice Involvement                          2
# Low Income                                   2
# English Language Learner                     2
# Comfortably Read and Write in English?       3
# Cultural barriers?                           3
# Single Parent                                3
# Displaced Homemaker                          2
# Spouse of Armed Forces Reduced Income        2
# Loss of Family Support                       2
# Seasonal farm worker?                        1
# Contact: First Name                          1
# Contact: Last Name                           1
# Status                                       7
# Date Completed                             169
# Assessment: Created Date                   841
# Contact: Approval Status                     0
# dtype: int64

# %% [markdown]
# #### Prep to clean
#
# There's only one such count for a few rows, which invalidate their need to be on this list and, instead, will be removed and given a note:
# * 'KY Region'  Every return is for 'SOAR', so only a note is needed.
# * 'Seasonal Farm Worker?'  This row only returns 'No', so it'll be removed.

# %%
def df_cleaning(df: pd.DataFrame) -> pd.DataFrame:
    columnsToRemove = [ # dropping columns of little consequence to any metric we might be exploring
        'KY Region',
        'Contact: Unique ID SSN',
	    'Contact: SSN Opt Out',
        'Contact: Mailing Zip/Postal Code',
	    'Seasonal farm worker?',
        'Contact: First Name',
	    'Contact: Last Name',
        'Status',
	    'Assessment: Created Date',
        'Contact: Approval Status'
    ]

    df = df.rename(columns={
        'Contact: Auto Id': 'Auto ID',
        'Contact: County': 'County',
        'Contact: Mailing State/Province': 'State',
        'Contact: Birthdate': 'Birthdate',
        'Contact: Gender': 'Gender',
        'Contact: Race': 'Race',
        'Contact: Veteran': 'Veteran'
    })

    df['State'] = ( # cleaning up the 'State' column so we can better look at demographics
        df['State']
            .str.strip() # removing whitespace
            .str.upper() # uppercase for ease of removal and change
            .replace({'KY': 'Kentucky'}) # specifically targeting the few cells that're 'KY'
            .str.title() # turning the caps back to title
    )

    df = df.drop(columnsToRemove, axis=1)

    fillElement = "Not Provided"    
    df = df.replace(np.nan, fillElement) # changing 'NaN' to "Not Provided"

    min_pct = 0.01 # giving a minimum percentage value for viable data
    df = df.dropna(axis=1, thresh=int(min_pct * len(df))) # precautionary 'thresh'old for relevant data or lack thereof
    df = df.drop_duplicates(subset=["Auto ID", "Date Completed"], keep="first", ignore_index=True) # being mindful that some students come back to take part in other cohorts

    return(df)

# %% [markdown]
# #### Further Notes
# * I think for demographic reasons we will keep most.
# * Keep the 'Date Completed' column, if only to match the unique identifier of 'Auto Id'.  Mentioned above in the code.

# %%
df_cleaned = df_cleaning(df)

df_cleaned
# Out:
#            Auto ID     State   County  Birthdate             Gender  \
# 0      202109-5224  Kentucky     Knox 1981-10-25             Female
# 1      202109-5230  Kentucky    Perry 2000-10-28  Prefer not to say
# 2      202109-5233  Kentucky   Morgan 1986-11-05               Male
# 3      202109-5236  Kentucky    Floyd 1978-01-22             Female
# 4      202109-5237  Kentucky     Knox 1992-04-16               Male
# ...            ...       ...      ...        ...                ...
# 2250  202506-23902  Kentucky    Floyd 1979-07-19               Male
# 2251  202506-23914  Kentucky  Pulaski 1991-06-03             Female
# 2252  202506-23927  Kentucky    Perry 1989-06-12               Male
# 2253  202506-23959  Kentucky   Laurel 1949-08-19             Female
# 2254  202506-23960  Kentucky   Harlan 1992-08-01             Female
#
#      Disability   Primary Disability               Race       Veteran  \
# 0            No  N/A - No Disability              White            No
# 1            No         Not Provided  Prefer Not To Say  Not Provided
# 2           Yes         Not Provided              White            No
# 3            No  N/A - No Disability              White            No
# 4            No         Not Provided              White            No
# ...         ...                  ...                ...           ...
# 2250         No         Not Provided              White            No
# 2251        Yes         Not Provided              White            No
# 2252         No         Not Provided              White            No
# 2253        Yes         Not Provided              White            No
# 2254         No         Not Provided              White            No
#
#                       Employment Status  ...  Justice Involvement Low Income  \
# 0                    Employed full-time  ...         Not Provided         No
# 1     Unemployed, actively seeking work  ...                   No        Yes
# 2     Unemployed, actively seeking work  ...                   No        Yes
# 3                    Employed full-time  ...                   No        Yes
# 4                    Employed full-time  ...                   No        Yes
# ...                                 ...  ...                  ...        ...
# 2250                 Employed full-time  ...                   No         No
# 2251  Unemployed, actively seeking work  ...                   No        Yes
# 2252                 Employed full-time  ...                   No         No
# 2253  Unemployed, actively seeking work  ...                   No         No
# 2254                 Employed full-time  ...                  Yes        Yes
#
#      English Language Learner Comfortably Read and Write in English?  \
# 0                Not Provided                           Not Provided
# 1                Not Provided                           Not Provided
# 2                Not Provided                           Not Provided
# 3                Not Provided                                     No
# 4                Not Provided                           Not Provided
# ...                       ...                                    ...
# 2250                       No                           Not Provided
# 2251                       No                           Not Provided
# 2252                       No                           Not Provided
# 2253                       No                           Not Provided
# 2254                       No                           Not Provided
#
#       Cultural barriers? Single Parent  Displaced Homemaker  \
# 0           Not Provided  Not Provided         Not Provided
# 1           Not Provided  Not Provided         Not Provided
# 2           Not Provided  Not Provided         Not Provided
# 3                     No           Yes                  Yes
# 4           Not Provided  Not Provided         Not Provided
# ...                  ...           ...                  ...
# 2250        Not Provided  Not Provided         Not Provided
# 2251        Not Provided  Not Provided         Not Provided
# 2252        Not Provided  Not Provided         Not Provided
# 2253        Not Provided  Not Provided         Not Provided
# 2254        Not Provided  Not Provided         Not Provided
#
#       Spouse of Armed Forces Reduced Income Loss of Family Support  \
# 0                              Not Provided           Not Provided
# 1                              Not Provided           Not Provided
# 2                              Not Provided           Not Provided
# 3                                        No                     No
# 4                              Not Provided           Not Provided
# ...                                     ...                    ...
# 2250                           Not Provided           Not Provided
# 2251                           Not Provided           Not Provided
# 2252                           Not Provided           Not Provided
# 2253                           Not Provided           Not Provided
# 2254                           Not Provided           Not Provided
#
#            Date Completed
# 0     2021-08-24 00:00:00
# 1     2021-08-25 00:00:00
# 2     2021-08-24 00:00:00
# 3     2021-08-24 00:00:00
# 4     2021-08-24 00:00:00
# ...                   ...
# 2250         Not Provided
# 2251         Not Provided
# 2252         Not Provided
# 2253         Not Provided
# 2254         Not Provided
#
# [2255 rows x 30 columns]

# %%
df_cleaned.to_csv('data/cleaned/cleaned applications.csv', index=False) # saving the cleaned file
